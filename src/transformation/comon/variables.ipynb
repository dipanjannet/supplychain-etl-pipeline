# %%
BRONZE_DATABASE_NAME = "scmdatalake_bronze"
SILVER_DATABASE_NAME = "scmdatalake_silver"
GOLD_DATABASE_NAME = "scmdatalake_gold"

# %%
SILVER_DATA_LAKE_PATH  = "abfss://scm-datalake@stgdataanalytics.dfs.core.windows.net/processing/"
GOLD_DATA_LAKE_PATH  = "abfss://scm-datalake@stgdataanalytics.dfs.core.windows.net/serving/"
