# %% [markdown]
# **CREATE SCHEMA**

# %%
# %sql

CREATE SCHEMA IF NOT EXISTS scmdatalake_silver_sap;
CREATE SCHEMA IF NOT EXISTS scmdatalake_gold_sap;

CREATE SCHEMA IF NOT EXISTS scmdatalake_silver_rest_api;
CREATE SCHEMA IF NOT EXISTS scmdatalake_gold_rest_api;

CREATE SCHEMA IF NOT EXISTS scmdatalake_silver_azure_sql;
CREATE SCHEMA IF NOT EXISTS scmdatalake_gold_azure_sql;
